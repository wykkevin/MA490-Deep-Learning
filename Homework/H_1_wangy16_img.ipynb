# %% [markdown]
# # Homework 1 Yuankai Wang

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.applications.inception_v3 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
dir_name = "ImageFolder"
image_list = os.listdir(dir_name)

# %%
model = InceptionV3(weights='imagenet')

# %%
for k in range(len(image_list)):
    path = dir_name + "/" + image_list[k]
    img = image.load_img(path,target_size=(299,299))
    x = image.img_to_array(img)
    x = np.expand_dims(x,axis=0)
    x = preprocess_input(x)
    y = model.predict(x)
    plt.imshow(img)
    plt.show()
    result = decode_predictions(y,top=1)[0][0]
    print("label: " + result[1] + "     prob = ",result[2])
# Out:
# label: comic_book     prob =  0.7661502
# label: sunglasses     prob =  0.48396316
# label: hourglass     prob =  0.3961209
